# %%
# !pip install opendatasets
# Out:
# ...
#      |████████████████████████████████| 76 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 58 kB 6.3 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#      |████████████████████████████████| 78 kB 8.6 MB/s
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73051 sha256=2cea317e1513e508e7ff27db22666588334ae7faab116d75d8a39dfc0d689129
#   Stored in directory: /home/jovyan/.cache/pip/wheels/62/d6/58/5853130f941e75b2177d281eb7e44b4a98ed46dd155f556dc5
# Successfully built kaggle
# ...

# %%
import opendatasets as od #od is objects here

# %%
dataset = "https://www.kaggle.com/yamqwe/nobel-prize-winnerse"

# %%
od.download(dataset)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
#   nikitajangid729
# Your Kaggle Key:
#   ································
# ...
# 100%|██████████| 1.90M/1.90M [00:00<00:00, 59.0MB/s]

# %%
import os #for reading the file

# %%
data_dir = "./nobel-prize-winnerse"

# %%
os.listdir(data_dir)
# Out:
# ['violin_nobel.png',
#  'age_year_category_distribution.png',
#  'countries_distribution.png',
#  'nobelTriples.csv',
#  'nobel_exploratory_gist.ipynb',
#  'nobel_prize_by_winner.csv',
#  'nobel_sparql.py',
#  'nobel_prizes_by_date.csv',
#  'age_year_regression.png']

# %%
#done for 14feb
